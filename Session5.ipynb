# %% [markdown]
# <a href="https://colab.research.google.com/github/somyaverma149/DSMP-learning/blob/main/Session5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Functions

# %%
def is_even(num):
  """
  This function returns if a given number is odd or even
  input - any valid integer
  output- odd/even
  created on - 7 july 2026
  """
  if num % 2 == 0:
    return 'even'
  else:
    return 'odd'

# %%
# function-name(input)
for i in range(1,11):
  x = is_even(i)
  print(x)
# Out:
# odd
# even
# odd
# even
# odd
# even
# odd
# even
# odd
# even

# %%
for i in range(1,11):
  x = is_even(2)
  print(x)
# Out:
# even
# even
# even
# even
# even
# even
# even
# even
# even
# even

# %% [markdown]
# point of views

# %%
is_even('hello')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1559/3078510824.py in <cell line: 0>()
# ----> 1 is_even('hello')
#
# /tmp/ipykernel_1559/3372941592.py in is_even(num)
#       6   created on - 7 july 2026
#       7   """
# ----> 8   if num % 2 == 0:
#       9     return 'even'
#      10   else:
#
# TypeError: not all arguments converted during string formatting

# %%
def is_even(num):
  """
  This function returns if a given number is odd or even
  input - any valid integer
  output- odd/even
  created on - 7 july 2026
  """
  if type(num) == int:
      if num % 2 == 0:
        return 'even'
      else:
        return 'odd'
  else:
    'pagal hai kya'

# %% [markdown]
# Parameters Vs Arguements

# %%
def power(a,b):
  return a**b

# %%
power(2,3)
# Out:
# 8

# %%
power(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1598/2828352081.py in <cell line: 0>()
# ----> 1 power(2)
#
# TypeError: power() missing 1 required positional argument: 'b'

# %%
def power(a=1,b=1):
  return a**b


  power(2)

# %%
power(2)
# Out:
# 2

# %%
power(1)
# Out:
# 1

# %%
# positional arguements
power(2,3)
# Out:
# 8

# %%
# keyword arguements
power(b=3,a=2)
# Out:
# 8

# %%
# *args and **kwargs
def multiply(a,b):
  return a*b

# %%
def multiply(a,b,c):
  return a*b*c

# %%
multiply(2,3,4)
# Out:
# 24

# %%
multiply(2,3)
# Out:
# 6

# %%
def multiply(*args):
  product = 1

  for i in args:
    product = product * i

    print(args)
    return product

# %%
multiply(1,2,3,4,5,6)
# Out:
# (1, 2, 3, 4, 5, 6)
# 1

# %%
def multiply(*salman):
  product = 1

  for i in salman:
    product = product * i

    print(salman)
    return product

# %%
print(is_even.__doc__)
# Out:
#   This function returns if a given number is odd or even
#   input - any valid integer
#   output- odd/even
#   created on - 7 july 2026

# %%
print(print.__doc__)
# Out:
# Prints the values to a stream, or to sys.stdout by default.
#
#   sep
#     string inserted between values, default a space.
#   end
#     string appended after the last value, default a newline.
#   file
#     a file-like object (stream); defaults to the current sys.stdout.
#   flush
#     whether to forcibly flush the stream.

# %%
# kwargs
def display(**kwargs):
  for (key,value) in kwargs.items():
    print(key,'->',value)

# %%
display(india='delhi',srilanka='colombo',nepal='kathmandu')
# Out:
# india -> delhi
# srilanka -> colombo
# nepal -> kathmandu

# %% [markdown]
# order of arguements matter(normal -> *args -> **kwargs

# %%
def multiply(*kwargs):
  product = 1

  for i in kwargs:
    product = product * i

    print(kwargs)
    return product

# %% [markdown]
# How functions are executed in memory?

# %%
def is_even(num):
  if num % 2 == 0:
    return 'even'
  else:
    return 'odd'

print(is_even(7))
# Out:
# odd

# %%
print(is_even(8))
# Out:
# even

# %% [markdown]
# Without return statement

# %%
L = [1,2,3]
print(L.append(4))
# Out:
# None

# %% [markdown]
# variable scope

# %%
def g(y):
  print(x)
  print(x+1)
x = 5
g(x)
print(x)
# Out:
# 5
# 6
# 5

# %%
g(6)
# Out:
# 5
# 6

# %%
def f(y):
  x = 1
  x += 1
  print(x)
x = 5
f(x)
print(x)
# Out:
# 2
# 5

# %%
def h(y):
  global x
  x += 1
x = 5
h(x)
print(x)
# Out:
# 6

# %% [markdown]
# Nested function

# %%
def f():
  def g():
    print('inside function g')
  g()
  print('inside function f')

# %%
f()
# Out:
# inside function g
# inside function f

# %%
def f():
  def g():
    print('inside function g')
    f()
  g()
  print('inside function f')

# %%
f()
# Out:
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# ...

# %%
def g(x):
  def h():
    x = 'abc'
  x = x + 1
  print('in g(x): x =',x)
  h()
  return(x)

# %%
x = 3
z = g(x)
# Out:
# in g(x): x = 4

# %% [markdown]
# First-Class citizen

# %%
def square(num):
  return num**2

type(square)


a = 2
id(square)
id(a)
# Out:
# 11645384

# %%
square(8)
# Out:
# 64

# %%
x = square
id(x)
x(3)
# Out:
# 9

# %%
a = 2
b = a
b
# Out:
# 2

# %%
del square

# %%
square(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1618/1056684087.py in <cell line: 0>()
# ----> 1 square(3)
#
# NameError: name 'square' is not defined

# %%
L = [1,2,3,4,square]

# %%
L
# Out:
# [1, 2, 3, 4, <function __main__.square(num)>]

# %%
L[-1](3)
# Out:
# 9

# %%
s = {square}

# %%
s
# Out:
# {<function __main__.square(num)>}

# %%
def f(x):
  def x(a,b):
    return a+b
  return x

val = f()(3,4)
print(val)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1618/846609693.py in <cell line: 0>()
#       4   return x
#       5
# ----> 6 val = f()(3,4)
#       7 print(val)
#
# TypeError: f() missing 1 required positional argument: 'x'

# %%
def func_a():
  print('inside func_a')

def func_b():
  print('inside func_b')
  return z()

print(func_b(func_a))

# %%
list(map(lambda x:x**2,[1,2,3,4,5]))
# Out:
# [1, 4, 9, 16, 25]
